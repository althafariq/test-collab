# %% [markdown]
# <a href="https://colab.research.google.com/github/althafariq/test-collab/blob/main/Untitled0.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
import pandas as pd

# %%
data = pd.read_csv('test.csv')
data
# Out:
#   nama  umur  tinggi
# 0    A   5.0   190.0
# 1    B   NaN   180.0
# 2    C  45.0     NaN

# %%
data2 = pd.read_csv('test2.csv')
data2
# Out:
#   nama  umur  tinggi
# 0    A  10.0    10.0
# 1    B   NaN    15.0
# 2    C  15.0     NaN

# %%
data2.groupby(['nama', 'umur'])
